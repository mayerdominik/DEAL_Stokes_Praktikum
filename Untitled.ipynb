# %%
import matplotlib.pyplot as plt
import numpy as np

data = []
with open("rel_error_at_points.txt", "r") as file:
    for line in file.read_lines():
        print(line)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       4 data = []
#       5 with open("rel_error_at_points.txt", "r") as file:
# ----> 6     for line in file.read_lines():
#       7         print(line)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'read_lines'
